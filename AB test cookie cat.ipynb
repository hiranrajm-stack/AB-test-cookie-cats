# %%
from statsmodels.stats.proportion import proportions_ztest

count = [8502, 8279]      #  Showing returners in each group
nobs = [44700, 45489]     # Showingtotal players in each group

z_stat, p_value = proportions_ztest(count, nobs)
print(z_stat, p_value)
# Out:
# 3.164358912748191 0.001554249975614329

# %%
from statsmodels.stats.proportion import confint_proportions_2indep

ci_low, ci_upp = confint_proportions_2indep(
    count1=8502, nobs1=44700,   # gate_30
    count2=8279, nobs2=45489,   # gate_40
    method='wald'
)
print(ci_low, ci_upp)
# Out:
# 0.00312104421152628 0.013281552418885546
